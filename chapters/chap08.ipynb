# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');

import thinkpython
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py

# %% [markdown]
# # Strings and Regular Expressions
#
# Strings are not like integers, floats, and booleans. A string is a **sequence**, which means it contains multiple values in a particular order.
# In this chapter we'll see how to access the values that make up a string, and we'll use functions that process strings.
#
# We'll also use regular expressions, which are a powerful tool for finding patterns in a string and performing operations like search and replace.
#
# As an exercise, you'll have a chance to apply these tools to a word game called Wordle.

# %% [markdown]
# ## A string is a sequence
#
# A string is a sequence of characters. A **character** can be a letter (in almost any alphabet), a digit, a punctuation mark, or white space.
#
# You can select a character from a string with the bracket operator.
# This example statement selects character number 1 from `fruit` and
# assigns it to `letter`:

# %%
fruit = 'banana'
letter = fruit[1]

# %% [markdown]
# The expression in brackets is an **index**, so called because it *indicates* which character in the sequence to select.
# But the result might not be what you expect.

# %%
letter
# Out:
# 'a'

# %% [markdown]
# The letter with index `1` is actually the second letter of the string.
# An index is an offset from the beginning of the string, so the offset of the first letter is `0`.

# %%
fruit[0]
# Out:
# 'b'

# %% [markdown]
# You can think of `'b'` as the 0th letter of `'banana'` -- pronounced "zero-eth".
#
# The index in brackets can be a variable.

# %%
i = 1
fruit[i]
# Out:
# 'a'

# %% [markdown]
# Or an expression that contains variables and operators.

# %%
fruit[i+1]
# Out:
# 'n'

# %% [markdown]
# But the value of the index has to be an integer -- otherwise you get a `TypeError`.

# %%
# %%expect TypeError
#
# fruit[1.5]
# Out:
# TypeError: string indices must be integers, not 'float'

# %% [markdown]
# As we saw in Chapter 1, we can use the built-in function `len` to get the length of a string.

# %%
n = len(fruit)
n
# Out:
# 6

# %% [markdown]
# To get the last letter of a string, you might be tempted to write this:

# %%
# %%expect IndexError
#
# fruit[n]
# Out:
# IndexError: string index out of range

# %% [markdown]
# But that causes an `IndexError` because there is no letter in `'banana'` with the index 6. Because we started counting at `0`, the six letters are numbered `0` to `5`. To get the last character, you have to subtract `1` from `n`:

# %%
fruit[n-1]
# Out:
# 'a'

# %% [markdown]
# But there's an easier way.
# To get the last letter in a string, you can use a negative index, which counts backward from the end.

# %%
fruit[-1]
# Out:
# 'a'

# %% [markdown]
# The index `-1` selects the last letter, `-2` selects the second to last, and so on.

# %% [markdown]
# ## String slices
#
# A segment of a string is called a **slice**.
# Selecting a slice is similar to selecting a character.

# %%
fruit = 'banana'
fruit[0:3]
# Out:
# 'ban'

# %% [markdown]
# The operator `[n:m]` returns the part of the string from the `n`th
# character to the `m`th character, including the first but excluding the second.
# This behavior is counterintuitive, but it might help to imagine the indices pointing *between* the characters, as in this figure:

# %%
from diagram import make_binding, Element, Value

binding = make_binding("fruit", ' b a n a n a ')
elements = [Element(Value(i), None) for i in range(7)]

# %%
import matplotlib.pyplot as plt
from diagram import diagram, adjust
from matplotlib.transforms import Bbox

width, height, x, y = [1.35, 0.54, 0.23, 0.39]

ax = diagram(width, height)
bbox = binding.draw(ax, x, y)
bboxes = [bbox]

def draw_elts(x, y, elements):
    for elt in elements:
        bbox = elt.draw(ax, x, y, draw_value=False)
        bboxes.append(bbox)

        x1 = (bbox.xmin + bbox.xmax) / 2
        y1 = bbox.ymax + 0.02
        y2 = y1 + 0.14
        handle = plt.plot([x1, x1], [y1, y2], ':', lw=0.5, color='gray')
        x += 0.105

draw_elts(x + 0.48, y - 0.25, elements)
bbox = Bbox.union(bboxes)
# adjust(x, y, bbox)

# %% [markdown]
# For example, the slice `[3:6]` selects the letters `ana`, which means that `6` is legal as part of a slice, but not legal as an index.
#
#
# If you omit the first index, the slice starts at the beginning of the string.

# %%
fruit[:3]
# Out:
# 'ban'

# %% [markdown]
# If you omit the second index, the slice goes to the end of the string:

# %%
fruit[3:]
# Out:
# 'ana'

# %% [markdown]
# If the first index is greater than or equal to the second, the result is an **empty string**, represented by two quotation marks:

# %%
fruit[3:3]
# Out:
# ''

# %% [markdown]
# An empty string contains no characters and has length 0.
#
# Continuing this example, what do you think `fruit[:]` means? Try it and
# see.

# %%
fruit[:]
# Out:
# 'banana'

# %% [markdown]
# ## Strings are immutable
#
# It is tempting to use the `[]` operator on the left side of an
# assignment, with the intention of changing a character in a string, like this:

# %%
# %%expect TypeError
#
# greeting = 'Hello, world!'
# greeting[0] = 'J'
# Out:
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# The result is a `TypeError`.
# In the error message, the "object" is the string and the "item" is the character
# we tried to assign.
# For now, an **object** is the same thing as a value, but we will refine that definition later.
#
# The reason for this error is that strings are **immutable**, which means you can't change an existing string.
# The best you can do is create a new string that is a variation of the original.

# %%
new_greeting = 'J' + greeting[1:]
new_greeting
# Out:
# 'Jello, world!'

# %% [markdown]
# This example concatenates a new first letter onto a slice of `greeting`.
# It has no effect on the original string.

# %%
greeting
# Out:
# 'Hello, world!'

# %% [markdown]
# ## String comparison
#
# The relational operators work on strings. To see if two strings are
# equal, we can use the `==` operator.

# %%
word = 'banana'

if word == 'banana':
    print('All right, banana.')
# Out:
# All right, banana.

# %% [markdown]
# Other relational operations are useful for putting words in alphabetical
# order:

# %%
def compare_word(word):
    if word < 'banana':
        print(word, 'comes before banana.')
    elif word > 'banana':
        print(word, 'comes after banana.')
    else:
        print('All right, banana.')

# %%
compare_word('apple')
# Out:
# apple comes before banana.

# %% [markdown]
# Python does not handle uppercase and lowercase letters the same way
# people do. All the uppercase letters come before all the lowercase
# letters, so:

# %%
compare_word('Pineapple')
# Out:
# Pineapple comes before banana.

# %% [markdown]
# To solve this problem, we can convert strings to a standard format, such as all lowercase, before performing the comparison.
# Keep that in mind if you have to defend yourself against a man armed with a Pineapple.

# %% [markdown]
# ## String methods
#
# Strings provide methods that perform a variety of useful operations.
# A method is similar to a function -- it takes arguments and returns a value -- but the syntax is different.
# For example, the method `upper` takes a string and returns a new string with all uppercase letters.
#
# Instead of the function syntax `upper(word)`, it uses the method syntax `word.upper()`.

# %%
word = 'banana'
new_word = word.upper()
new_word

# %% [markdown]
# This use of the dot operator specifies the name of the method, `upper`, and the name of the string to apply the method to, `word`.
# The empty parentheses indicate that this method takes no arguments.
#
# A method call is called an **invocation**; in this case, we would say that we are invoking `upper` on `word`.

# %% [markdown]
# ## Writing files
#
# String operators and methods are useful for reading and writing text files.
# As an example, we'll work with the text of *Dracula*, a novel by Bram Stoker that is available from Project Gutenberg (<https://www.gutenberg.org/ebooks/345>).

# %%
import os

if not os.path.exists('pg345.txt'):
    # !wget https://www.gutenberg.org/cache/epub/345/pg345.txt
# Out:
# --2025-05-07 09:49:49--  https://www.gutenberg.org/cache/epub/345/pg345.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 890394 (870K) [text/plain]
# Saving to: ‘pg345.txt’
#
# pg345.txt           100%[===================>] 869.53K  5.46MB/s    in 0.2s
#
# 2025-05-07 09:49:49 (5.46 MB/s) - ‘pg345.txt’ saved [890394/890394]

# %% [markdown]
# I've downloaded the book in a plain text file called `pg345.txt`, which we can open for reading like this:

# %%
reader = open('pg345.txt')

# %% [markdown]
# In addition to the text of the book, this file contains a section at the beginning with information about the book and a section at the end with information about the license.
# Before we process the text, we can remove this extra material by finding the special lines at the beginning and end that begin with `'***'`.
#
# The following function takes a line and checks whether it is one of the special lines.
# It uses the `startswith` method, which checks whether a string starts with a given sequence of characters.

# %%
def is_special_line(line):
    return line.startswith('*** ')

# %% [markdown]
# We can use this function to loop through the lines in the file and print only the special lines.

# %%
for line in reader:
    if is_special_line(line):
        print(line.strip())
# Out:
# *** START OF THE PROJECT GUTENBERG EBOOK DRACULA ***
# *** END OF THE PROJECT GUTENBERG EBOOK DRACULA ***

# %% [markdown]
# Now let's create a new file, called `pg345_cleaned.txt`, that contains only the text of the book.
# In order to loop through the book again, we have to open it again for reading.
# And, to write a new file, we can open it for writing.

# %%
reader = open('pg345.txt')
writer = open('pg345_cleaned.txt', 'w')

# %% [markdown]
# `open` takes an optional parameters that specifies the "mode" -- in this example, `'w'` indicates that we're opening the file for writing.
# If the file doesn't exist, it will be created; if it already exists, the contents will be replaced.
#
# As a first step, we'll loop through the file until we find the first special line.

# %%
for line in reader:
    if is_special_line(line):
        break

# %% [markdown]
# The `break` statement "breaks" out of the loop -- that is, it causes the loop to end immediately, before we get to the end of the file.
#
# When the loop exits, `line` contains the special line that made the conditional true.

# %%
line
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK DRACULA ***\n'

# %% [markdown]
# Because `reader` keeps track of where it is in the file, we can use a second loop to pick up where we left off.
#
# The following loop reads the rest of the file, one line at a time.
# When it finds the special line that indicates the end of the text, it breaks out of the loop.
# Otherwise, it writes the line to the output file.

# %%
for line in reader:
    if is_special_line(line):
        break
    writer.write(line)

# %% [markdown]
# When this loop exits, `line` contains the second special line.

# %%
line
# Out:
# '*** END OF THE PROJECT GUTENBERG EBOOK DRACULA ***\n'

# %% [markdown]
# At this point `reader` and `writer` are still open, which means we could keep reading lines from `reader` or writing lines to `writer`.
# To indicate that we're done, we can close both files by invoking the `close` method.

# %%
reader.close()
writer.close()

# %% [markdown]
# To check whether this process was successful, we can read the first few lines from the new file we just created.

# %%
for line in open('pg345_cleaned.txt'):
    line = line.strip()
    if len(line) > 0:
        print(line)
    if line.endswith('Stoker'):
        break
# Out:
# DRACULA
# _by_
# Bram Stoker

# %% [markdown]
# The `endswith` method checks whether a string ends with a given sequence of characters.

# %% [markdown]
# ## Find and replace
#
# In the Icelandic translation of *Dracula* from 1901, the name of one of the characters was changed from "Jonathan" to "Thomas".
# To make this change in the English version, we can loop through the book, use the `replace` method to replace one name with another, and write the result to a new file.
#
# We'll start by counting the lines in the cleaned version of the file.

# %%
total = 0
for line in open('pg345_cleaned.txt'):
    total += 1

total
# Out:
# 15477

# %% [markdown]
# To see whether a line contains "Jonathan", we can use the `in` operator, which checks whether this sequence of characters appears anywhere in the line.

# %%
total = 0
for line in open('pg345_cleaned.txt'):
    if 'Jonathan' in line:
        total += 1

total
# Out:
# 199

# %% [markdown]
# There are 199 lines that contain the name, but that's not quite the total number of times it appears, because it can appear more than once in a line.
# To get the total, we can use the `count` method, which returns the number of times a sequence appears in a string.

# %%
total = 0
for line in open('pg345_cleaned.txt'):
    total += line.count('Jonathan')

total
# Out:
# 200

# %% [markdown]
# Now we can replace `'Jonathan'` with `'Thomas'` like this:

# %%
writer = open('pg345_replaced.txt', 'w')

for line in open('pg345_cleaned.txt'):
    line = line.replace('Jonathan', 'Thomas')
    writer.write(line)

# %% [markdown]
# The result is a new file called `pg345_replaced.txt` that contains a version of *Dracula* where Jonathan Harker is called Thomas.

# %%
total = 0
for line in open('pg345_replaced.txt'):
    total += line.count('Thomas')

total
# Out:
# 207

# %% [markdown]
# ## Regular expressions
#
# If we know exactly what sequence of characters we're looking for, we can use the `in` operator to find it and the `replace` method to replace it.
# But there is another tool, called a **regular expression** that can also perform these operations -- and a lot more.
#
# To demonstrate, I'll start with a simple example and we'll work our way up.
# Suppose, again, that we want to find all lines that contain a particular word.
# For a change, let's look for references to the titular character of the book, Count Dracula.
# Here's a line that mentions him.

# %%
text = "I am Dracula; and I bid you welcome, Mr. Harker, to my house."

# %% [markdown]
# And here's the **pattern** we'll use to search.

# %%
pattern = 'Dracula'

# %% [markdown]
# A module called `re` provides functions related to regular expressions.
# We can import it like this and use the `search` function to check whether the pattern appears in the text.

# %%
import re

result = re.search(pattern, text)
result
# Out:
# <re.Match object; span=(5, 12), match='Dracula'>

# %% [markdown]
# If the pattern appears in the text, `search` returns a `Match` object that contains the results of the search.
# Among other information, it has a variable named `string` that contains the text that was searched.

# %%
result.string
# Out:
# 'I am Dracula; and I bid you welcome, Mr. Harker, to my house.'

# %% [markdown]
# It also provides a method called `group` that returns the part of the text that matched the pattern.

# %%
result.group()
# Out:
# 'Dracula'

# %% [markdown]
# And it provides a method called `span` that returns the index in the text where the pattern starts and ends.

# %%
result.span()
# Out:
# (5, 12)

# %% [markdown]
# If the pattern doesn't appear in the text, the return value from `search` is `None`.

# %%
result = re.search('Count', text)
print(result)
# Out:
# None

# %% [markdown]
# So we can check whether the search was successful by checking whether the result is `None`.

# %%
result == None
# Out:
# True

# %% [markdown]
# Putting all that together, here's a function that loops through the lines in the book until it finds one that matches the given pattern, and returns the `Match` object.

# %%
def find_first(pattern):
    for line in open('pg345_cleaned.txt'):
        result = re.search(pattern, line)
        if result != None:
            return result

# %% [markdown]
# We can use it to find the first mention of a character.

# %%
result = find_first('Harker')
result.string
# Out:
# 'CHAPTER I. Jonathan Harker’s Journal\n'

# %% [markdown]
# For this example, we didn't have to use regular expressions -- we could have done the same thing more easily with the `in` operator.
# But regular expressions can do things the `in` operator cannot.
#
# For example, if the pattern includes the vertical bar character, `'|'`, it can match either the sequence on the left or the sequence on the right.
# Suppose we want to find the first mention of Mina Murray in the book, but we are not sure whether she is referred to by first name or last.
# We can use the following pattern, which matches either name.

# %%
pattern = 'Mina|Murray'
result = find_first(pattern)
result.string
# Out:
# 'CHAPTER V. Letters—Lucy and Mina\n'

# %% [markdown]
# We can use a pattern like this to see how many times a character is mentioned by either name.
# Here's a function that loops through the book and counts the number of lines that match the given pattern.

# %%
def count_matches(pattern):
    count = 0
    for line in open('pg345_cleaned.txt'):
        result = re.search(pattern, line)
        if result != None:
            count += 1
    return count

# %% [markdown]
# Now let's see how many times Mina is mentioned.

# %%
count_matches('Mina|Murray')
# Out:
# 229

# %% [markdown]
# The special character `'^'` matches the beginning of a string, so we can find a line that starts with a given pattern.

# %%
result = find_first('^Dracula')
result.string
# Out:
# 'Dracula, jumping to his feet, said:--\n'

# %% [markdown]
# And the special character `'$'` matches the end of a string, so we can find a line that ends with a given pattern (ignoring the newline at the end).

# %%
result = find_first('Harker$')
result.string
# Out:
# 'by five o’clock, we must start off; for it won’t do to leave Mrs. Harker\n'

# %% [markdown]
# ## String substitution
#
# Bram Stoker was born in Ireland, and when *Dracula* was published in 1897, he was living in England.
# So we would expect him to use the British spelling of words like "centre" and "colour".
# To check, we can use the following pattern, which matches either "centre" or the American spelling "center".

# %%
pattern = 'cent(er|re)'

# %% [markdown]
# In this pattern, the parentheses enclose the part of the pattern the vertical bar applies to.
# So this pattern matches a sequence that starts with `'cent'` and ends with either `'er'` or `'re'`.

# %%
result = find_first(pattern)
result.string
# Out:
# 'horseshoe of the Carpathians, as if it were the centre of some sort of\n'

# %% [markdown]
# As expected, he used the British spelling.
#
# We can also check whether he used the British spelling of "colour".
# The following pattern uses the special character `'?'`, which means that the previous character is optional.

# %%
pattern = 'colou?r'

# %% [markdown]
# This pattern matches either "colour" with the `'u'` or "color" without it.

# %%
result = find_first(pattern)
line = result.string
line
# Out:
# 'undergarment with long double apron, front, and back, of coloured stuff\n'

# %% [markdown]
# Again, as expected, he used the British spelling.
#
# Now suppose we want to produce an edition of the book with American spellings.
# We can use the `sub` function in the `re` module, which does **string substitution**.

# %%
re.sub(pattern, 'color', line)
# Out:
# 'undergarment with long double apron, front, and back, of colored stuff\n'

# %% [markdown]
# The first argument is the pattern we want to find and replace, the second is what we want to replace it with, and the third is the string we want to search.
# In the result, you can see that "colour" has been replaced with "color".

# %%
# I used this function to search for lines to use as examples

def all_matches(pattern):
    for line in open('pg345_cleaned.txt'):
        result = re.search(pattern, line)
        if result:
            print(line.strip())

# %%
# Here's the pattern I used (which uses some features we haven't seen)

names = r'(?<!\.\s)[A-Z][a-zA-Z]+'

all_matches(names)
# Out:
# DRACULA DRACULA
# Bram Stoker Bram
# [Illustration: colophon] Illustration
# NEW YORK NEW
# GROSSET & DUNLAP GROSSET
# _Publishers_ Publishers
# Copyright, 1897, in the United States of America, according Copyright
# to Act of Congress, by Bram Stoker Act
# [_All rights reserved._] All
# PRINTED IN THE UNITED STATES PRINTED
# AT AT
# THE COUNTRY LIFE PRESS, GARDEN CITY, N.Y. THE
# TO TO
# MY DEAR FRIEND MY
# HOMMY-BEG HOMMY
# Contents Contents
# CHAPTER I. Jonathan Harker’s Journal CHAPTER
# CHAPTER II. Jonathan Harker’s Journal CHAPTER
# CHAPTER III. Jonathan Harker’s Journal CHAPTER
# CHAPTER IV. Jonathan Harker’s Journal CHAPTER
# CHAPTER V. Letters—Lucy and Mina CHAPTER
# CHAPTER VI. Mina Murray’s Journal CHAPTER
# CHAPTER VII. Cutting from “The Dailygraph,” 8 August CHAPTER
# CHAPTER VIII. Mina Murray’s Journal CHAPTER
# CHAPTER IX. Mina Murray’s Journal CHAPTER
# CHAPTER X. Mina Murray’s Journal CHAPTER
# CHAPTER XI. Lucy Westenra’s Diary CHAPTER
# CHAPTER XII. Dr. Seward’s Diary CHAPTER
# CHAPTER XIII. Dr. Seward’s Diary CHAPTER
# CHAPTER XIV. Mina Harker’s Journal CHAPTER
# CHAPTER XV. Dr. Seward’s Diary CHAPTER
# CHAPTER XVI. Dr. Seward’s Diary CHAPTER
# CHAPTER XVII. Dr. Seward’s Diary CHAPTER
# CHAPTER XVIII. Dr. Seward’s Diary CHAPTER
# CHAPTER XIX. Jonathan Harker’s Journal CHAPTER
# CHAPTER XX. Jonathan Harker’s Journal CHAPTER
# CHAPTER XXI. Dr. Seward’s Diary CHAPTER
# CHAPTER XXII. Jonathan Harker’s Journal CHAPTER
# CHAPTER XXIII. Dr. Seward’s Diary CHAPTER
# CHAPTER XXIV. Dr. Seward’s Phonograph Diary, spoken by Van Helsing CHAPTER
# CHAPTER XXV. Dr. Seward’s Diary CHAPTER
# CHAPTER XXVI. Dr. Seward’s Diary CHAPTER
# CHAPTER XXVII. Mina Harker’s Journal CHAPTER
# How these papers have been placed in sequence will be made manifest in How
# DRACULA DRACULA
# CHAPTER I CHAPTER
# JONATHAN HARKER’S JOURNAL JONATHAN
# (_Kept in shorthand._) Kept
# _3 May. Bistritz._--Left Munich at 8:35 P. M., on 1st May, arriving at May
# Vienna early next morning; should have arrived at 6:46, but train was an Vienna
# hour late. Buda-Pesth seems a wonderful place, from the glimpse which I Pesth
# impression I had was that we were leaving the West and entering the West
# East; the most western of splendid bridges over the Danube, which is East
# here of noble width and depth, took us among the traditions of Turkish Turkish
# We left in pretty good time, and came after nightfall to Klausenburgh. We
# Here I stopped for the night at the Hotel Royale. I had for dinner, or Here
# very good but thirsty. (_Mem._, get recipe for Mina.) I asked the Mem
# Carpathians. I found my smattering of German very useful here; indeed, I Carpathians
# Having had some time at my disposal when in London, I had visited the Having
# British Museum, and made search among the books and maps in the library British
# regarding Transylvania; it had struck me that some foreknowledge of the Transylvania
# Transylvania, Moldavia and Bukovina, in the midst of the Carpathian Transylvania
# mountains; one of the wildest and least known portions of Europe. I was Europe
# Castle Dracula, as there are no maps of this country as yet to compare Castle
# with our own Ordnance Survey maps; but I found that Bistritz, the post Ordnance
# town named by Count Dracula, is a fairly well-known place. I shall enter Count
# travels with Mina. Mina
# In the population of Transylvania there are four distinct nationalities: In
# Saxons in the South, and mixed with them the Wallachs, who are the Saxons
# descendants of the Dacians; Magyars in the West, and Szekelys in the Dacians
# East and North. I am going among the latter, who claim to be descended East
# from Attila and the Huns. This may be so, for when the Magyars conquered Attila
# the country in the eleventh century they found the Huns settled in it. I Huns
# horseshoe of the Carpathians, as if it were the centre of some sort of Carpathians
# imaginative whirlpool; if so my stay may be very interesting. (_Mem._, I Mem
# must ask the Count all about them.) Count
# very excellent dish, which they call “impletata.” (_Mem._, get recipe Mem
# more unpunctual are the trains. What ought they to be in China? China
# All day long we seemed to dawdle through a country which was full of All
# saw coming through France and Germany, with short jackets and round hats France
# Slovaks, who were more barbarian than the rest, with their big cow-boy Slovaks
# set down at once as some old Oriental band of brigands. They are, Oriental
# It was on the dark side of twilight when we got to Bistritz, which is a It
# Borgo Pass leads from it into Bukovina--it has had a very stormy Borgo
# Count Dracula had directed me to go to the Golden Krone Hotel, which I Count
# said, “The Herr Englishman?” “Yes,” I said, “Jonathan Harker.” She The
# “My Friend.--Welcome to the Carpathians. I am anxiously expecting My
# start for Bukovina; a place on it is kept for you. At the Borgo Bukovina
# Pass my carriage will await you and will bring you to me. I trust Pass
# that your journey from London has been a happy one, and that you London
# “Your friend, Your
# “DRACULA.” DRACULA
# _4 May._--I found that my landlord had got a letter from the Count, May
# pretended that he could not understand my German. This could not be German
# was all he knew. When I asked him if he knew Count Dracula, and could Count
# Just before I was leaving, the old lady came up to my room and said in a Just
# “Must you go? Oh! young Herr, must you go?” She was in such an excited Must
# state that she seemed to have lost her grip of what German she knew, and German
# “Do you know what day it is?” I answered that it was the fourth of May. Do
# She shook her head as she said again: She
# “Oh, yes! I know that! I know that, but do you know what day it is?” On Oh
# “It is the eve of St. George’s Day. Do you not know that to-night, when It
# full sway? Do you know where you are going, and what you are going to?” Do
# She was in such evident distress that I tried to comfort her, but She
# did not know what to do, for, as an English Churchman, I have been English
# rosary round my neck, and said, “For your mother’s sake,” and went out For
# ever reach Mina before I do, let it bring my good-bye. Here comes the Mina
# _5 May. The Castle._--The grey of the morning has passed, and the sun is May
# left Bistritz, let me put down my dinner exactly. I dined on what they Bistritz
# style of the London cat’s meat! The wine was Golden Mediasch, which London
# When I got on the coach the driver had not taken his seat, and I saw him When
# cheering to me, for amongst them were “Ordog”--Satan, “pokol”--hell, Ordog
# thing, one being Slovak and the other Servian for something that is Slovak
# either were-wolf or vampire. (_Mem._, I must ask the Count about these Mem
# When we started, the crowd round the inn door, which had by this time When
# first, but on learning that I was English, he explained that it was a English
# green hills of what they call here the “Mittel Land” ran the road, Mittel
# time in reaching Borgo Prund. I was told that this road is in summertime Borgo
# the Carpathians, for it is an old tradition that they are not to be kept Carpathians
# in too good order. Of old the Hospadars would not repair them, lest the Hospadars
# Turk should think that they were preparing to bring in foreign troops, Turk
# Beyond the green swelling hills of the Mittel Land rose mighty slopes Beyond
# of forest up to the lofty steeps of the Carpathians themselves. Right Carpathians
# “Look! Isten szek!”--“God’s seat!”--and he crossed himself reverently. Look
# As we wound on our endless way, and the sun sank lower and lower behind As
# we passed Cszeks and Slovaks, all in picturesque attire, but I noticed Cszeks
# peasants, the Cszeks with their white, and the Slovaks with their Cszeks
# Pass, the dark firs stood out here and there against the background of Pass
# Carpathians seem to wind ceaselessly through the valleys. Sometimes the Carpathians
# but the driver would not hear of it. “No, no,” he said; “you must not No
# before you go to sleep.” The only stop he would make was a moment’s The
# When it grew dark there seemed to be some excitement amongst the When
# side and to frown down upon us; we were entering on the Borgo Pass. One Borgo
# Bistritz--the sign of the cross and the guard against the evil eye. Bistritz
# Then, as we flew along, the driver leaned forward, and on each side the Then
# some little time; and at last we saw before us the Pass opening out on Pass
# which was to take me to the Count. Each moment I expected to see the Count
# The passengers drew back with a sigh of gladness, which seemed to mock The
# thought it was “An hour less than the time.” Then turning to me, he said An
# in German worse than my own:-- German
# “There is no carriage here. The Herr is not expected after all. He will There
# now come on to Bukovina, and return to-morrow or the next day; better Bukovina
# the next day.” Whilst he was speaking the horses began to neigh and Whilst
# “You are early to-night, my friend.” The man stammered in reply:-- You
# “The English Herr was in a hurry,” to which the stranger replied:-- The
# “That is why, I suppose, you wished him to go on to Bukovina. You cannot That
# deceive me, my friend; I know too much, and my horses are swift.” As he As
# companions whispered to another the line from Burger’s “Lenore”:-- Burger
# “Denn die Todten reiten schnell”-- Denn
# (“For the dead travel fast.”) For
# The strange driver evidently heard the words, for he looked up with a The
# putting out his two fingers and crossing himself. “Give me the Herr’s Give
# swept into the darkness of the Pass. As I looked back I saw the steam Pass
# on their way to Bukovina. As they sank into the darkness I felt a Bukovina
# excellent German:-- German
# “The night is chill, mein Herr, and my master the Count bade me take all The
# Then a dog began to howl somewhere in a farmhouse far down the road--a Then
# now sighed softly through the Pass, a wild howling began, which seemed Pass
# time, after going to the far side of the Pass, he suddenly turned down a Pass
# Soon we were hemmed in with trees, which in places arched right over the Soon
# It grew colder and colder still, and fine, powdery snow began to fall, It
# Suddenly, away on our left, I saw a faint flickering blue flame. The Suddenly
# Once the flame appeared so near the road, that even in the darkness Once
# At last there came a time when the driver went further afield than he At
# For myself, I felt a sort of paralysis of fear. It is only when a man For
# All at once the wolves began to howl as though the moonlight had had All
# When I could see again the driver was climbing into the calèche, and the When
# CHAPTER II CHAPTER
# JONATHAN HARKER’S JOURNAL--_continued_ JONATHAN
# _5 May._--I must have been asleep, for certainly if I had been fully May
# When the calèche stopped, the driver jumped down and held out his hand When
# What sort of grim adventure was it on which I had embarked? Was this a What
# explain the purchase of a London estate to a foreigner? Solicitor’s London
# clerk! Mina would not like that. Solicitor--for just before leaving Mina
# London I got word that my examination was successful; and I am now a London
# and among the Carpathians. All I could do now was to be patient, and to Carpathians
# Just as I had come to this conclusion I heard a heavy step approaching Just
# Within, stood a tall old man, clean shaven save for a long white Within
# gesture, saying in excellent English, but with a strange intonation:-- English
# “Welcome to my house! Enter freely and of your own will!” He made no Welcome
# “Welcome to my house. Come freely. Go safely; and leave something of the Welcome
# happiness you bring!” The strength of the handshake was so much akin to The
# “Count Dracula?” He bowed in a courtly way as he replied:-- Count
# “I am Dracula; and I bid you welcome, Mr. Harker, to my house. Come in; Dracula
# the night air is chill, and you must need to eat and rest.” As he was As
# “Nay, sir, you are my guest. It is late, and my people are not Nay
# available. Let me see to your comfort myself.” He insisted on carrying He
# The Count halted, putting down my bags, closed the door, and crossing The
# fresh--which sent a hollow roar up the wide chimney. The Count himself Count
# “You will need, after your journey, to refresh yourself by making your You
# The light and warmth and the Count’s courteous welcome seemed to have The
# I handed to him the sealed letter which Mr. Hawkins had entrusted to me. Mr
# He opened it and read it gravely; then, with a charming smile, he handed He
# The Count himself came forward and took off the cover of a dish, and I The
# and a salad and a bottle of old Tokay, of which I had two glasses, was Tokay
# my supper. During the time I was eating it the Count asked me many Count
# By this time I had finished my supper, and by my host’s desire had drawn By
# His face was a strong--a very strong--aquiline, with high bridge of the His
# Hitherto I had noticed the backs of his hands as they lay on his knees Hitherto
# point. As the Count leaned over me and his hands touched me, I could not Count
# not conceal. The Count, evidently noticing it, drew back; and with a Count
# down below in the valley the howling of many wolves. The Count’s eyes Count
# “Listen to them--the children of the night. What music they make!” Listen
# Seeing, I suppose, some expression in my face strange to him, he Seeing
# “Ah, sir, you dwellers in the city cannot enter into the feelings of the Ah
# hunter.” Then he rose and said:-- Then
# “But you must be tired. Your bedroom is all ready, and to-morrow you But
# so sleep well and dream well!” With a courteous bow, he opened for me With
# _7 May._--It is again early morning, but I have rested and enjoyed the May
# There are certainly odd deficiencies in the house, considering the There
# The curtains and upholstery of the chairs and sofas and the hangings of The
# though in excellent order. I saw something like them in Hampton Court, Hampton
# Some time after I had finished my meal--I do not know whether to call it Some
# the castle until I had asked the Count’s permission. There was Count
# In the library I found, to my great delight, a vast number of English In
# newspapers. A table in the centre was littered with English magazines English
# economy, botany, geology, law--all relating to England and English life England
# London Directory, the “Red” and “Blue” books, Whitaker’s Almanac, the London
# Army and Navy Lists, and--it somehow gladdened my heart to see it--the Army
# Law List. Law
# Whilst I was looking at the books, the door opened, and the Count Whilst
# since I had the idea of going to London, have given me many, many hours London
# of pleasure. Through them I have come to know your great England; and to England
# your mighty London, to be in the midst of the whirl and rush of London
# To you, my friend, I look that I know it to speak.” To
# “But, Count,” I said, “you know and speak English thoroughly!” He bowed But
# “Indeed,” I said, “you speak excellently.” Indeed
# “Not so,” he answered. “Well, I know that, did I move and speak in your Not
# London, none there are who would not know me for a stranger. That is not London
# speaking if he hear my words, ‘Ha, ha! a stranger!’ I have been so long Ha
# be master of me. You come to me not alone as agent of my friend Peter Peter
# Hawkins, of Exeter, to tell me all about my new estate in London. You Hawkins
# learn the English intonation; and I would that you tell me when I make English
# Of course I said all I could about being willing, and asked if I might Of
# come into that room when I chose. He answered: “Yes, certainly,” and Yes
# “You may go anywhere you wish in the castle, except where the doors are You
# “We are in Transylvania; and Transylvania is not England. Our ways are We
# This led to much conversation; and as it was evident that he wanted to This
# Sometimes he sheered off the subject, or turned the conversation by Sometimes
# where treasure has been concealed. “That treasure has been hidden,” he That
# Wallachian, the Saxon, and the Turk. Why, there is hardly a foot of soil Wallachian
# Austrian and the Hungarian came up in hordes, and the patriots went out Austrian
# “But how,” said I, “can it have remained so long undiscovered, when But
# The Count smiled, and as his lips ran back over his gums, the long, The
# “Because your peasant is at heart a coward and a fool! Those flames only Because
# “There you are right,” I said. “I know no more than the dead where even There
# to look for them.” Then we drifted into other matters. Then
# “Come,” he said at last, “tell me of London and of the house which you Come
# have procured for me.” With an apology for my remissness, I went into my With
# in the study or library, and I found the Count lying on the sofa, Count
# reading, of all things in the world, an English Bradshaw’s Guide. When I English
# “Well, but, my friend, is it not needful that I should? When I go there Well
# I shall be all alone, and my friend Harker Jonathan--nay, pardon me, I Harker
# Jonathan Harker will not be by my side to correct and aid me. He will be Jonathan
# in Exeter, miles away, probably working at papers of the law with my Exeter
# other friend, Peter Hawkins. So!” Peter
# We went thoroughly into the business of the purchase of the estate at We
# Purfleet. When I had told him the facts and got his signature to the Purfleet
# Mr. Hawkins, he began to ask me how I had come across so suitable a Mr
# “At Purfleet, on a by-road, I came across just such a place as seemed to At
# “The estate is called Carfax, no doubt a corruption of the old _Quatre The
# Face_, as the house is four-sided, agreeing with the cardinal points of Face
# When I had finished, he said:-- When
# also that there is a chapel of old times. We Transylvanian nobles love Transylvanian
# be alone with my thoughts when I may.” Somehow his words and his look Somehow
# Presently, with an excuse, he left me, asking me to put all my papers Presently
# England, as if that map had been much used. On looking at it I found in England
# that one was near London on the east side, manifestly where his new London
# estate was situated; the other two were Exeter, and Whitby on the Exeter
# Yorkshire coast. Yorkshire
# It was the better part of an hour when the Count returned. “Aha!” he It
# said; “still at your books? Good! But you must not work always. Come; I Good
# am informed that your supper is ready.” He took my arm, and we went into He
# Count again excused himself, as he had dined out on his being away from Count
# After supper I smoked, as on the last evening, and the Count stayed with After
# They say that people who are near death die generally at the change to They
# with preternatural shrillness through the clear morning air; Count Count
# Dracula, jumping to his feet, said:-- Dracula
# “Why, there is the morning again! How remiss I am to let you stay up so Why
# England less interesting, so that I may not forget how time flies by England
# _8 May._--I began to fear as I wrote in this book that I was getting too May
# me; but would that that were all! If there were any one to talk to I If
# could bear it, but there is no one. I have only the Count to speak with, Count
# and heard the Count’s voice saying to me, “Good-morning.” I started, for Count
# but did not notice it at the moment. Having answered the Count’s Count
# This time there could be no error, for the man was close to me, and I This
# the mirror! The whole room behind me was displayed; but there was no The
# feeling of uneasiness which I always have when the Count is near; but at Count
# round to look for some sticking plaster. When the Count saw my face, his Count
# “Take care,” he said, “take care how you cut yourself. It is more Take
# dangerous than you think in this country.” Then seizing the shaving Then
# glass, he went on: “And this is the wretched thing that has done the And
# When I went into the dining-room, breakfast was prepared; but I could When
# not find the Count anywhere. So I breakfasted alone. It is strange that Count
# as yet I have not seen the Count eat or drink. He must be a very Count
# peculiar man! After breakfast I did a little exploring in the castle. I After
# went out on the stairs, and found a room looking towards the South. The South
# touching anything! As far as the eye can reach is a sea of green tree As
# But I am not in heart to describe beauty, for when I had seen the view I But
# The castle is a veritable prison, and I am a prisoner! The
# CHAPTER III CHAPTER
# JONATHAN HARKER’S JOURNAL--_continued_ JONATHAN
# When I found that I was a prisoner a sort of wild feeling came over me. When
# the Count. He knows well that I am imprisoned; and as he has done it Count
# shut, and knew that the Count had returned. He did not come at once into Count
# This gave me a fright, for if there is no one else in the castle, it This
# must have been the Count himself who was the driver of the coach that Count
# hand in silence. How was it that all the people at Bistritz and on the Bistritz
# coach had some terrible fear for me? What meant the giving of the What
# crucifix, of the garlic, of the wild rose, of the mountain ash? Bless Bless
# a tangible help, in conveying memories of sympathy and comfort? Some Some
# mind about it. In the meantime I must find out all I can about Count Count
# Dracula, as it may help me to understand. To-night he may talk of Dracula
# _Midnight._--I have had a long talk with the Count. I asked him a few Midnight
# questions on Transylvania history, and he warmed up to the subject Transylvania
# “We Szekelys have a right to be proud, for in our veins flows the blood We
# in the whirlpool of European races, the Ugric tribe bore down from European
# Iceland the fighting spirit which Thor and Wodin gave them, which their Iceland
# Berserkers displayed to such fell intent on the seaboards of Europe, ay, Berserkers
# and of Asia and Africa too, till the peoples thought that the Asia
# the Huns, whose warlike fury had swept the earth like a living flame, Huns
# old witches, who, expelled from Scythia had mated with the devils in the Scythia
# desert. Fools, fools! What devil or what witch was ever so great as What
# Attila, whose blood is in these veins?” He held up his arms. “Is it a Attila
# Magyar, the Lombard, the Avar, the Bulgar, or the Turk poured his Magyar
# thousands on our frontiers, we drove them back? Is it strange that when Is
# Arpad and his legions swept through the Hungarian fatherland he found us Arpad
# here when he reached the frontier; that the Honfoglalas was completed Honfoglalas
# there? And when the Hungarian flood swept eastward, the Szekelys were And
# claimed as kindred by the victorious Magyars, and to us for centuries Magyars
# was trusted the guarding of the frontier of Turkey-land; ay, and more Turkey
# than that, endless duty of the frontier guard, for, as the Turks say, Turks
# ‘water sleeps, and enemy is sleepless.’ Who more gladly than we Who
# throughout the Four Nations received the ‘bloody sword,’ or at its Four
# warlike call flocked quicker to the standard of the King? When was King
# redeemed that great shame of my nation, the shame of Cassova, when the Cassova
# flags of the Wallach and the Magyar went down beneath the Crescent? Who Wallach
# was it but one of my own race who as Voivode crossed the Danube and beat Voivode
# the Turk on his own ground? This was a Dracula indeed! Woe was it that Turk
# Turk and brought the shame of slavery on them! Was it not this Dracula, Turk
# again brought his forces over the great river into Turkey-land; who, Turkey
# slaughtered, since he knew that he alone could ultimately triumph! They They
# without a leader? Where ends the war without a brain and heart to Where
# conduct it? Again, when, after the battle of Mohács, we threw off the Again
# Hungarian yoke, we of the Dracula blood were amongst their leaders, for Hungarian
# Szekelys--and the Dracula as their heart’s blood, their brains, and Szekelys
# Hapsburgs and the Romanoffs can never reach. The warlike days are over. Hapsburgs
# Blood is too precious a thing in these days of dishonourable peace; and Blood
# It was by this time close on morning, and we went to bed. (_Mem._, this It
# diary seems horribly like the beginning of the “Arabian Nights,” for Arabian
# everything has to break off at cockcrow--or like the ghost of Hamlet’s Hamlet
# _12 May._--Let me begin with facts--bare, meagre facts, verified by May
# observation, or my memory of them. Last evening when the Count came from Count
# matters I had been examining at Lincoln’s Inn. There was a certain Lincoln
# method in the Count’s inquiries, so I shall try to put them down in Count
# First, he asked if a man in England might have two solicitors or more. I First
# “I shall illustrate. Your friend and mine, Mr. Peter Hawkins, from under Mr
# the shadow of your beautiful cathedral at Exeter, which is far from Exeter
# London, buys for me through your good self my place at London. Good! Now London
# sought the services of one so far off from London instead of some one London
# served save my wish only; and as one of London residence might, perhaps, London
# I, who have much of affairs, wish to ship goods, say, to Newcastle, or Newcastle
# Durham, or Harwich, or Dover, might it not be that it could with more Durham
# “But,” said he, “I could be at liberty to direct myself. Is it not so?” But
# “Of course,” I replied; and “such is often done by men of business, who Of
# “Good!” he said, and then went on to ask about the means of making Good
# “Have you written since your first letter to our friend Mr. Peter Have
# Hawkins, or to any other?” It was with some bitterness in my heart that Hawkins
# “Then write now, my young friend,” he said, laying a heavy hand on my Then
# “Do you wish me to stay so long?” I asked, for my heart grew cold at the Do
# What could I do but bow acceptance? It was Mr. Hawkins’s interest, not What
# mine, and I had to think of him, not myself; and besides, while Count Count
# Dracula was speaking, there was that in his eyes and in his bearing Dracula
# could have no choice. The Count saw his victory in my bow, and his Count
# home to them. Is it not so?” As he spoke he handed me three sheets of As
# now, but to write fully to Mr. Hawkins in secret, and also to Mina, for Mr
# to her I could write in shorthand, which would puzzle the Count, if he Count
# book whilst the Count wrote several notes, referring as he wrote them to Count
# One of the letters was directed to Samuel F. Billington, No. 7, The One
# Crescent, Whitby, another to Herr Leutner, Varna; the third was to Crescent
# Coutts & Co., London, and the fourth to Herren Klopstock & Billreuth, Coutts
# bankers, Buda-Pesth. The second and fourth were unsealed. I was just Buda
# to resume my book before the Count, holding still another letter in his Count
# evening. You will, I hope, find all things as you wish.” At the door he At
# “Let me advise you, my dear young friend--nay, let me warn you with all Let
# warned! Should sleep now or ever overcome you, or be like to do, then Should
# safe. But if you be not careful in this respect, then”--He finished his He
# _Later._--I endorse the last words written, but this time there is no Later
# When he left me I went to my room. After a little while, not hearing any When
# towards the South. There was some sense of freedom in the vast expanse, South
# It is destroying my nerve. I start at my own shadow, and am full of all It
# the rooms, that the windows of the Count’s own room would look out. The Count
# What I saw was the Count’s head coming out from the window. I did not What
# What manner of man is this, or what manner of creature is it in the What
# _15 May._--Once more have I seen the Count go out in his lizard fashion. May
# He moved downwards in a sidelong way, some hundred feet down, and a good He
# door was locked, and the key was gone! That key must be in the Count’s That
# presence of the Count, and after trying a little to school my nerves, I Count
# _Later: the Morning of 16 May._--God preserve my sanity, for to this I Later
# Whilst I live on here there is but one thing to hope for, that I may not Whilst
# hateful place the Count is the least dreadful to me; that to him alone I Count
# purpose. Great God! merciful God! Let me be calm, for out of that way God
# have puzzled me. Up to now I never quite knew what Shakespeare meant Shakespeare
# when he made Hamlet say:-- Hamlet
# “My tablets! quick, my tablets! My
# ’Tis meet that I put it down,” etc., Tis
# The habit of entering accurately must help to soothe me. The
# The Count’s mysterious warning frightened me at the time; it frightens The
# When I had written in my diary and had fortunately replaced the book and When
# pen in my pocket I felt sleepy. The Count’s warning came into my mind, Count
# noses, like the Count, and great dark, piercing eyes that seemed to be Count
# day it should meet Mina’s eyes and cause her pain; but it is the truth. Mina
# They whispered together, and then they all three laughed--such a They
# The fair girl shook her head coquettishly, and the other two urged her The
# “Go on! You are first, and we shall follow; yours is the right to Go
# begin.” The other added:-- The
# “He is young and strong; there are kisses for us all.” I lay quiet, He
# The fair girl advanced and bent over me till I could feel the movement The
# But at that instant, another sensation swept through me as quick as But
# lightning. I was conscious of the presence of the Count, and of his Count
# passion. But the Count! Never did I imagine such wrath and fury, even to Count
# “How dare you touch him, any of you? How dare you cast eyes on him when How
# I had forbidden it? Back, I tell you all! This man belongs to me! Beware Back
# how you meddle with him, or you’ll have to deal with me.” The fair girl, The
# “You yourself never loved; you never love!” On this the other women You
# of fiends. Then the Count turned, after looking at my face attentively, Count
# “Yes, I too can love; you yourselves can tell it from the past. Is it Yes
# not so? Well, now I promise you that when I am done with him you shall Well
# “Are we to have nothing to-night?” said one of them, with a low laugh, Are
# Then the horror overcame me, and I sank down unconscious. Then
# CHAPTER IV CHAPTER
# JONATHAN HARKER’S JOURNAL--_continued_ JONATHAN
# I awoke in my own bed. If it be that I had not dreamt, the Count must Count
# thing I am glad: if it was that the Count carried me here and undressed Count
# _18 May._--I have been down to look at that room again in daylight, for May
# _19 May._--I am surely in the toils. Last night the Count asked me in May
# Bistritz. I would fain have rebelled, but felt that in the present state Bistritz
# of things it would be madness to quarrel openly with the Count whilst I Count
# be held over at Bistritz until due time in case chance would admit of my Bistritz
# “The first should be June 12, the second June 19, and the third June The
# _28 May._--There is a chance of escape, or at any rate of being able to May
# send word home. A band of Szgany have come to the castle, and are Szgany
# encamped in the courtyard. These Szgany are gipsies; I have notes of Szgany
# of them in Hungary and Transylvania, who are almost outside all law. Hungary
# They attach themselves as a rule to some great noble or _boyar_, and They
# save superstition, and they talk only their own varieties of the Romany Romany
# I have written the letters. Mina’s is in shorthand, and I simply ask Mr. Mr
# Hawkins to communicate with her. To her I have explained my situation, Hawkins
# letters not carry, then the Count shall not yet know my secret or the Count
# read. As the Count did not come in, I have written here.... Count
# The Count has come. He sat down beside me, and said in his smoothest The
# “The Szgany has given me these, of which, though I know not whence they The
# it--“one is from you, and to my friend Peter Hawkins; the other”--here Peter
# other is a vile thing, an outrage upon friendship and hospitality! It is It
# not signed. Well! so it cannot matter to us.” And he calmly held letter And
# “The letter to Hawkins--that I shall, of course, send on, since it is The
# unknowingly I did break the seal. Will you not cover it again?” He held He
# When, an hour or two after, the Count came quietly into the room, his When
# “So, my friend, you are tired? Get to bed. There is the surest rest. I So
# _31 May._--This morning when I woke I thought I would provide myself May
# Every scrap of paper was gone, and with it all my notes, my memoranda, Every
# The suit in which I had travelled was gone, and also my overcoat and The
# _17 June._--This morning, as I was sitting on the edge of my bed June
# With joy I hurried to the window, and saw drive into the yard two great With
# each pair a Slovak, with his wide hat, great nail-studded belt, dirty Slovak
# Then I ran to the window and cried to them. They looked up at me Then
# stupidly and pointed, but just then the “hetman” of the Szgany came out, Szgany
# The leiter-wagons contained great, square boxes, with handles of thick The
# rope; these were evidently empty by the ease with which the Slovaks Slovaks
# yard, the Slovaks were given some money by the Szgany, and spitting on Slovaks
# _24 June, before morning._--Last night the Count left me early, and June
# thought I would watch for the Count, for there is something going on. Count
# The Szgany are quartered somewhere in the castle and are doing work of The
# something coming out of the Count’s window. I drew back and watched Count
# and in my garb, too! This, then, is his new scheme of evil: that he will This
# It makes me rage to think that this can go on, and whilst I am shut up It
# I thought I would watch for the Count’s return, and for a long time sat Count
# Something made me start up, a low, piteous howling of dogs somewhere far Something
# was becoming hypnotised! Quicker and quicker danced the dust; the Quicker
# When a couple of hours had passed I heard something stirring in the When
# Count’s room, something like a sharp wail quickly suppressed; and then Count
# As I sat I heard a sound in the courtyard without--the agonised cry of a As
# “Monster, give me my child!” Monster
# She threw herself on her knees, and raising up her hands, cried the same She
# Somewhere high overhead, probably on the tower, I heard the voice of the Somewhere
# Count calling in his harsh, metallic whisper. His call seemed to be Count
# There was no cry from the woman, and the howling of the wolves was but There
# What shall I do? what can I do? How can I escape from this dreadful What
# _25 June, morning._--No man knows till he has suffered from the night June
# Let me not think of it. Action! Let
# It has always been at night-time that I have been molested or It
# Count in the daylight. Can it be that he sleeps when others wake, that Count
# he may be awake whilst they sleep? If I could only get into his room! If
# But there is no possible way. The door is always locked, no way for me. But
# Yes, there is a way, if one dares to take it. Where his body has gone Yes
# window. Why should not I imitate him, and go in by his window? The The
# calf’s, and the dreaded Hereafter may still be open to me. God help me Hereafter
# in my task! Good-bye, Mina, if I fail; good-bye, my faithful friend and Good
# second father; good-bye, all, and last of all Mina! Mina
# _Same day, later._--I have made the effort, and God, helping me, have Same
# well the direction and distance of the Count’s window, and made for it Count
# around for the Count, but, with surprise and gladness, made a discovery. Count
# The room was empty! It was barely furnished with odd things, which The
# corner--gold of all kinds, Roman, and British, and Austrian, and Roman
# Hungarian, and Greek and Turkish money, covered with a film of dust, as Hungarian
# At one corner of the room was a heavy door. I tried it, for, since I At
# brought by the Slovaks. There was nobody about, and I made search for Slovaks
# There, in one of the great boxes, of which there were fifty in all, on a There
# pile of newly dug earth, lay the Count! He was either dead or asleep, I Count
# By the side of the box was its cover, pierced with holes here and there. By
# leaving the Count’s room by the window, crawled again up the castle Count
# _29 June._--To-day is the date of my last letter, and the Count has June
# I was awakened by the Count, who looked at me as grimly as a man can Count
# “To-morrow, my friend, we must part. You return to your beautiful To
# England, I to some work which may have such an end that we may never England
# Szgany, who have some labours of their own here, and also come some Szgany
# Slovaks. When they have gone, my carriage shall come for you, and shall Slovaks
# bear you to the Borgo Pass to meet the diligence from Bukovina to Borgo
# Bistritz. But I am in hopes that I shall see more of you at Castle Bistritz
# Dracula.” I suspected him, and determined to test his sincerity. Dracula
# Sincerity! It seems like a profanation of the word to write it in Sincerity
# “Why may I not go to-night?” Why
# “Because, dear sir, my coachman and horses are away on a mission.” Because
# “But I would walk with pleasure. I want to get away at once.” He smiled, But
# “And your baggage?” And
# The Count stood up, and said, with a sweet courtesy which made me rub my The
# “You English have a saying which is close to my heart, for its spirit is You
# that which rules our _boyars_: ‘Welcome the coming; speed the parting Welcome
# guest.’ Come with me, my dear young friend. Not an hour shall you wait Come
# you so suddenly desire it. Come!” With a stately gravity, he, with the With
# “Hark!” Hark
# Close at hand came the howling of many wolves. It was almost as if the Close
# To my intense astonishment I saw that it was unlocked. Suspiciously, I To
# As the door began to open, the howling of the wolves without grew louder As
# to struggle at the moment against the Count was useless. With such Count
# continued slowly to open, and only the Count’s body stood in the gap. Count
# Suddenly it struck me that this might be the moment and means of my Suddenly
# was a diabolical wickedness in the idea great enough for the Count, and Count
# “Shut the door; I shall wait till morning!” and covered my face with my Shut
# powerful arm, the Count threw the door shut, and the great bolts clanged Count
# In silence we returned to the library, and after a minute or two I went In
# to my own room. The last I saw of Count Dracula was his kissing his hand Count
# Judas in hell might be proud of. Judas
# When I was in my room and about to lie down, I thought I heard a When
# deceived me, I heard the voice of the Count:-- Count
# “Back, back, to your own place! Your time is not yet come. Wait! Have Back
# patience! To-night is mine. To-morrow night is yours!” There was a low, To
# the end? To-morrow! to-morrow! Lord, help me, and those to whom I am To
# _30 June, morning._--These may be the last words I ever write in this June
# on my knees, for I determined that if Death came he should find me Death
# At last I felt that subtle change in the air, and knew that the morning At
# With a glad heart, I opened my door and ran down to the hall. I had seen With
# But the door would not move. Despair seized me. I pulled, and pulled, at But
# Count. Count
# Then a wild desire took me to obtain that key at any risk, and I Then
# determined then and there to scale the wall again and gain the Count’s Count
# down the wall, as before, into the Count’s room. It was empty, but that Count
# The great box was in the same place, close against the wall, but the lid The
# something which filled my very soul with horror. There lay the Count, Count
# key. Then I stopped and looked at the Count. There was a mocking smile Count
# was helping to transfer to London, where, perhaps, for centuries to come London
# cracking of whips; the Szgany and the Slovaks of whom the Count had Szgany
# contained the vile body, I ran from the place and gained the Count’s Count
# With strained ears, I listened, and heard downstairs the grinding of the With
# As I write there is in the passage below a sound of many tramping feet As
# The door is shut, and the chains rattle; there is a grinding of the key The
# Hark! in the courtyard and down the rocky way the roll of heavy wheels, Hark
# the crack of whips, and the chorus of the Szgany as they pass into the Szgany
# I am alone in the castle with those awful women. Faugh! Mina is a woman, Mina
# and there is nought in common. They are devils of the Pit! Pit
# And then away for home! away to the quickest and nearest train! away And
# At least God’s mercy is better than that of these monsters, and the At
# Good-bye, all! Mina! Good
# CHAPTER V CHAPTER
# _Letter from Miss Mina Murray to Miss Lucy Westenra._ Letter
# “_9 May._ May
# “My dearest Lucy,-- My
# “Forgive my long delay in writing, but I have been simply overwhelmed Forgive
# lately, because I want to keep up with Jonathan’s studies, and I have Jonathan
# be able to be useful to Jonathan, and if I can stenograph well enough I Jonathan
# two-pages-to-the-week-with-Sunday-squeezed-in-a-corner diaries, but a Sunday
# intended for them. I may show it to Jonathan some day if there is in it Jonathan
# plans when we meet. I have just had a few hurried lines from Jonathan Jonathan
# from Transylvania. He is well, and will be returning in about a week. I Transylvania
# countries. I wonder if we--I mean Jonathan and I--shall ever see them Jonathan
# “Your loving Your
# “MINA. MINA
# “Tell me all the news when you write. You have not told me anything for Tell
# _Letter, Lucy Westenra to Mina Murray_. Letter
# “_17, Chatham Street_, Chatham
# “_Wednesday_. Wednesday
# “My dearest Mina,-- My
# last Pop. Some one has evidently been telling tales. That was Mr. Pop
# Holmwood. He often comes to see us, and he and mamma get on very well Holmwood
# engaged to Jonathan. He is an excellent _parti_, being handsome, well Jonathan
# off, and of good birth. He is a doctor and really clever. Just fancy! He He
# bore. That is slang again, but never mind; Arthur says that every day. Arthur
# There, it is all out. Mina, we have told all our secrets to each other There
# to speak more. Oh, Mina, couldn’t you guess? I love him. I am blushing Mina
# words. But oh, Mina, I love him; I love him; I love him! There, that Mina
# prayers; and, Mina, pray for my happiness. Mina
# “LUCY. LUCY
# _Letter, Lucy Westenra to Mina Murray_. Letter
# “_24 May_. May
# “My dearest Mina,-- My
# “Thanks, and thanks, and thanks again for your sweet letter. It was so Thanks
# “My dear, it never rains but it pours. How true the old proverbs are. My
# Here am I, who shall be twenty in September, and yet I never had a Here
# Just fancy! THREE proposals in one day! Isn’t it awful! I feel sorry, Just
# really and truly sorry, for two of the poor fellows. Oh, Mina, I am so Mina
# But, for goodness’ sake, don’t tell any of the girls, or they would be But
# least. Some girls are so vain! You and I, Mina dear, who are engaged and You
# it a secret, dear, from _every one_, except, of course, Jonathan. You Jonathan
# Arthur. A woman ought to tell her husband everything--don’t you think Arthur
# quite as fair as they should be. Well, my dear, number One came just One
# before lunch. I told you of him, Dr. John Seward, the lunatic-asylum Dr
# me, Mina, very straightforwardly. He told me how dear I was to him, Mina
# free a man might have hope. And then, Mina, I felt a sort of duty to Mina
# wanted a friend I must count him one of my best. Oh, Mina dear, I can’t Mina
# “_Evening._ Evening
# “Arthur has just gone, and I feel in better spirits than when I left Arthur
# off, so I can go on telling you about the day. Well, my dear, number Two Two
# came after lunch. He is such a nice fellow, an American from Texas, and American
# with poor Desdemona when she had such a dangerous stream poured in her Desdemona
# don’t, for there was Mr. Morris telling us his stories, and Arthur never Mr
# told any, and yet---- My dear, I am somewhat previous. Mr. Quincey P. My
# Morris found me alone. It seems that a man always does find a girl Morris
# alone. No, he doesn’t, for Arthur tried twice to _make_ a chance, and I Arthur
# beforehand that Mr. Morris doesn’t always speak slang--that is to say, Mr
# to hear him talk American slang, and whenever I was present, and there American
# ever speak slang; I do not know if Arthur likes it, as I have never Arthur
# heard him use any as yet. Well, Mr. Morris sat down beside me and looked Mr
# “‘Miss Lucy, I know I ain’t good enough to regulate the fixin’s of your Miss
# “Well, he did look so good-humoured and so jolly that it didn’t seem Well
# half so hard to refuse him as it did poor Dr. Seward; so I said, as Dr
# feeling a bit serious too--I know, Mina, you will think me a horrid Mina
# “‘Lucy, you are an honest-hearted girl, I know. I should not be here Lucy
# to another, is there any one else that you care for? And if there is And
# “My dear Mina, why are men so noble when we women are so little worthy My
# of them? Here was I almost making fun of this great-hearted, true Here
# her, and save all this trouble? But this is heresy, and I must not say But
# Mr. Morris’s brave eyes, and I told him out straight:-- Mr
# “‘Yes, there is some one I love, though he has not told me yet that he Yes
# “‘That’s my brave girl. It’s better worth being late for a chance of That
# lonely walk between this and Kingdom Come. Won’t you give me one kiss? Kingdom
# It’ll be something to keep off the darkness now and then. You can, you It
# yet.’ That quite won me, Mina, for it _was_ brave and sweet of him, and That
# “‘Little girl, I hold your hand, and you’ve kissed me, and if these Little
# honesty to me, and good-bye.’ He wrung my hand, and taking up his hat, He
# “Ever your loving Ever
# “LUCY. LUCY
# “P.S.--Oh, about number Three--I needn’t tell you of number Three, need Oh
# I? Besides, it was all so confused; it seemed only a moment from his Besides
# ungrateful to God for all His goodness to me in sending to me such a God
# “Good-bye.” Good
# _Dr. Seward’s Diary._ Dr
# (Kept in phonograph) Kept
# _25 May._--Ebb tide in appetite to-day. Cannot eat, cannot rest, so May
# (_Mem._, under what circumstances would I _not_ avoid the pit of hell?) Mem
# _Omnia Romæ venalia sunt._ Hell has its price! _verb. sap._ If there be Omnia
# R. M. Renfield, ætat 59.--Sanguine temperament; great physical strength; Sanguine
# _Letter, Quincey P. Morris to Hon. Arthur Holmwood._ Letter
# “_25 May._ May
# “My dear Art,-- My
# “We’ve told yarns by the camp-fire in the prairies; and dressed one We
# another’s wounds after trying a landing at the Marquesas; and drunk Marquesas
# healths on the shore of Titicaca. There are more yarns to be told, and Titicaca
# Korea, Jack Seward. He’s coming, too, and we both want to mingle our Korea
# that God has made and the best worth winning. We promise you a hearty God
# “Yours, as ever and always, Yours
# “QUINCEY P. MORRIS.” QUINCEY
# _Telegram from Arthur Holmwood to Quincey P. Morris._ Telegram
# “_26 May._ May
# “Count me in every time. I bear messages which will make both your ears Count
# “ART.” ART
# CHAPTER VI CHAPTER
# MINA MURRAY’S JOURNAL MINA
# _24 July. Whitby._--Lucy met me at the station, looking sweeter and July
# lovelier than ever, and we drove up to the house at the Crescent in Crescent
# Esk, runs through a deep valley, which broadens out as it comes near the Esk
# pictures we see of Nuremberg. Right over the town is the ruin of Whitby Nuremberg
# Abbey, which was sacked by the Danes, and which is the scene of part of Abbey
# “Marmion,” where the girl was built up in the wall. It is a most noble Marmion
# Whitby, for it lies right over the town, and has a full view of the Whitby
# harbour and all up the bay to where the headland called Kettleness Kettleness
# The harbour lies below me, with, on the far side, one long granite wall The
# It is nice at high water; but when the tide is out it shoals away to It
# nothing, and there is merely the stream of the Esk, running between Esk
# He is a funny old man. He must be awfully old, for his face is all He
# nearly a hundred, and that he was a sailor in the Greenland fishing Greenland
# fleet when Waterloo was fought. He is, I am afraid, a very sceptical Waterloo
# person, for when I asked him about the bells at sea and the White Lady White
# Mind, I don’t say that they never was, but I do say that they wasn’t in Mind
# but not for a nice young lady like you. Them feet-folks from York and York
# Leeds that be always eatin’ cured herrin’s an’ drinkin’ tea an’ lookin’ Leeds
# He hobbled away, and I could see him hurrying, as well as he could, down He
# _1 August._--I came up here an hour ago with Lucy, and we had a most August
# ...
# houses are very few here now, and the Professor says that the last horse Professor
# drive. We shall get to the Pass in daylight; we do not want to arrive Pass
# will to-morrow bring to us? We go to seek the place where my poor We
# that He will deign to watch over my husband and those dear to us both, He
# and who are in such deadly peril. As for me, I am not worthy in His His
# sight. Alas! I am unclean to His eyes, and shall be until He may deign His
# to let me stand forth in His sight as one of those who have not incurred His
# His wrath. His
# _Memorandum by Abraham Van Helsing._ Memorandum
# _4 November._--This to my old and true friend John Seward, M.D., of November
# Purfleet, London, in case I may not see him. It may explain. It is Purfleet
# alive--Madam Mina aiding me. It is cold, cold; so cold that the grey Madam
# affected Madam Mina; she has been so heavy of head all day that she was Madam
# not like herself. She sleeps, and sleeps, and sleeps! She who is usual She
# However, to-night she is more _vif_. Her long sleep all day have refresh However
# God’s will be done--whatever it may be, and whithersoever it may lead! God
# Now to the historical, for as Madam Mina write not in her stenography, I Now
# We got to the Borgo Pass just after sunrise yesterday morning. When I We
# couch with furs, and Madam Mina, lying down, yield herself as usual, but Madam
# before, came the answer: “darkness and the swirling of water.” Then she Then
# woke, bright and radiant and we go on our way and soon reach the Pass. Pass
# At this time and place, she become all on fire with zeal; some new At
# “This is the way.” This
# “How know you it?” I ask. How
# “Of course I know it,” she answer, and with a pause, add: “Have not my Of
# Jonathan travelled it and wrote of his travel?” Jonathan
# At first I think somewhat strange, but soon I see that there be only one At
# road from the Bukovina to Bistritz, which is more wide and hard, and Bukovina
# So we came down this road; when we meet other ways--not always were we So
# they go on so patient. By-and-by we find all the things which Jonathan Jonathan
# hours and hours. At the first, I tell Madam Mina to sleep; she try, and Madam
# look down and find Madam Mina still sleep. It is now not far off sunset Madam
# For we are going up, and up; and all is oh! so wild and rocky, as though For
# Then I arouse Madam Mina. This time she wake with not much trouble, and Then
# Madam Mina laugh, and I turn and look at her. She is now quite awake, Madam
# and look so well as I never saw her since that night at Carfax when we Carfax
# first enter the Count’s house. I am amaze, and not at ease then; but she Count
# _5 November, morning._--Let me be accurate in everything, for though you November
# that I, Van Helsing, am mad--that the many horrors and the so long Van
# All yesterday we travel, ever getting closer to the mountains, and All
# frowning precipices and much falling water, and Nature seem to have held Nature
# sometime her carnival. Madam Mina still sleep and sleep; and though I Mina
# she is with that Vampire baptism. “Well,” said I to myself, “if it be Vampire
# night.” As we travel on the rough road, for a road of an ancient and As
# with a sense of guilt and of time passed, and found Madam Mina still Madam
# steep-rising hill, on summit of which was such a castle as Jonathan tell Jonathan
# I woke Madam Mina, and again tried to hypnotise her; but alas! Madam
# Madam Mina, now awake and more charming than ever, sit comfortable amid Madam
# where Madam Mina sat; and over the ring I passed some of the wafer, and Madam
# “Will you not come over to the fire?” for I wished to make a test of Will
# “Why not go on?” I asked. She shook her head, and, coming back, sat Why
# Presently the horses began to scream, and tore at their tethers till I Presently
# all the terrible anxiety. It was as though my memories of all Jonathan’s Jonathan
# feared for my dear Madam Mina when these weird figures drew near and Madam
# “No! No! Do not go without. Here you are safe!” I turned to her, and No
# “But you? It is for you that I fear!” whereat she laughed--a laugh, low But
# “Fear for _me_! Why fear for me? None safer in all the world from them Fear
# Then, alas! I knew. Did I not, I would soon have learned, for the Then
# the Holy circle. Then they began to materialise till--if God have not Holy
# in actual flesh the same three women that Jonathan saw in the room, when Jonathan
# lips. They smiled ever at poor dear Madam Mina; and as their laugh came Madam
# her, and said in those so sweet tingling tones that Jonathan said were Jonathan
# “Come, sister. Come to us. Come! Come!” In fear I turned to my poor Come
# Madam Mina, and my heart with gladness leapt like flame; for oh! the Madam
# Wafer, advanced on them towards the fire. They drew back before me, and Wafer
# approach, me, whilst so armed, nor Madam Mina whilst she remained within Madam
# And so we remained till the red of the dawn to fall through the And
# At the first coming of the dawn the horrid figures melted in the At
# Instinctively, with the dawn coming, I turned to Madam Mina, intending Instinctively
# work. Madam Mina still sleeps; and, God be thanked! she is calm in her Mina
# _Jonathan Harker’s Journal._ Jonathan
# _4 November, evening._--The accident to the launch has been a terrible November
# and by now my dear Mina would have been free. I fear to think of her, Mina
# follow on the track. I note this whilst Godalming is getting ready. We Godalming
# have our arms. The Szgany must look out if they mean fight. Oh, if only Szgany
# Morris and Seward were with us. We must only hope! If I write no more Morris
# Good-bye, Mina! God bless and keep you. Good
# _Dr. Seward’s Diary._ Dr
# _5 November._--With the dawn we saw the body of Szgany before us dashing November
# _Dr. Van Helsing’s Memorandum._ Dr
# _5 November, afternoon._--I am at least sane. Thank God for that mercy November
# Madam Mina sleeping within the Holy circle, I took my way to the castle. Madam
# The blacksmith hammer which I took in the carriage from Veresti was The
# Then I bethought me of my dear Madam Mina, and I was in terrible plight. Then
# The dilemma had me between his horns. The
# Her, I had not dare to take into this place, but left safe from the Her
# Vampire in that Holy circle; and yet even there would be the wolf! I Vampire
# submit, if it were God’s will. At any rate it was only death and God
# the grave of the Vampire! So I make my choice to go on with my work. Vampire
# Vampire sleep, so full of life and voluptuous beauty that I shudder as Vampire
# wanton Un-Dead have hypnotise him; and he remain on and on, till sunset Un
# come, and the Vampire sleep be over. Then the beautiful eyes of the fair Vampire
# kiss--and man is weak. And there remain one more victim in the Vampire Vampire
# fold; one more to swell the grim and grisly ranks of the Un-Dead!... Un
# There is some fascination, surely, when I am moved by the mere presence There
# as the lairs of the Count have had. Yes, I was moved--I, Van Helsing, Count
# of a clarion. For it was the voice of my dear Madam Mina that I heard. Madam
# Then I braced myself again to my horrid task, and found by wrenching Then
# which, like Jonathan I had seen to gather herself out of the atoms of Jonathan
# with new emotion. But God be thanked, that soul-wail of my dear Madam God
# Mina had not died out of my ears; and, before the spell could be wrought Mina
# there had been only three of these Un-Dead phantoms around us in the Un
# night, I took it that there were no more of active Un-Dead existent. Un
# There was one great tomb more lordly than all the rest; huge it was, and There
# DRACULA. DRACULA
# This then was the Un-Dead home of the King-Vampire, to whom so many more This
# Before I began to restore these women to their dead selves through my Before
# awful work, I laid in Dracula’s tomb some of the Wafer, and so banished Dracula
# him from it, Un-Dead, for ever. Un
# Then began my terrible task, and I dreaded it. Had it been but one, it Then
# had been easy, comparative. But three! To begin twice more after I had To
# Miss Lucy, what would it not be with these strange ones who had survived Miss
# Oh, my friend John, but it was butcher work; had I not been nerved by Oh
# till all was over, God be thanked, my nerve did stand. Had I not seen God
# left my work undone. But it is over! And the poor souls, I can pity them And
# for a short moment ere fading. For, friend John, hardly had my knife John
# Before I left the castle I so fixed its entrances that never more can Before
# the Count enter there Un-Dead. Count
# When I stepped into the circle where Madam Mina slept, she woke from her When
# “Come!” she said, “come away from this awful place! Let us go to meet my Come
# husband who is, I know, coming towards us.” She was looking thin and She
# And so with trust and hope, and yet full of fear, we go eastward to meet And
# our friends--and _him_--whom Madam Mina tell me that she _know_ are Madam
# _Mina Harker’s Journal._ Mina
# _6 November._--It was late in the afternoon when the Professor and I November
# took our way towards the east whence I knew Jonathan was coming. We did Jonathan
# clear line of Dracula’s castle cut the sky; for we were so deep under Dracula
# Carpathian mountains was far below it. We saw it in all its grandeur, Carpathian
# full of terror. I knew from the way Dr. Van Helsing was searching about Dr
# In a little while the Professor signalled to me, so I got up and joined In
# hand and drew me in: “See!” he said, “here you will be in shelter; and See
# if the wolves do come I can meet them one by one.” He brought in our He
# “Look! Madam Mina, look! look!” I sprang up and stood beside him on the Look
# On the cart was a great square chest. My heart leaped as I saw it, for I On
# well I knew that at sunset the Thing, which was till then imprisoned Thing
# pursuit. In fear I turned to the Professor; to my consternation, Professor
# “At least you shall be safe here from _him_!” He took the glasses from At
# “See,” he said, “they come quickly; they are flogging the horses, and See
# galloping as hard as they can.” He paused and went on in a hollow He
# “They are racing for the sunset. We may be too late. God’s will be They
# done!” Down came another blinding rush of driving snow, and the whole Down
# “Look! Look! Look! See, two horsemen follow fast, coming up from the Look
# south. It must be Quincey and John. Take the glass. Look before the snow Quincey
# blots it all out!” I took it and looked. The two men might be Dr. Seward Dr
# and Mr. Morris. I knew at all events that neither of them was Jonathan. Mr
# At the same time I _knew_ that Jonathan was not far off; looking around At
# break-neck speed. One of them I knew was Jonathan, and the other I took, Jonathan
# of course, to be Lord Godalming. They, too, were pursuing the party with Lord
# the cart. When I told the Professor he shouted in glee like a schoolboy, Professor
# laid his Winchester rifle ready for use against the boulder at the Winchester
# opening of our shelter. “They are all converging,” he said. “When the They
# It was strange to see the snow falling in such heavy flakes close to us, It
# Every instant seemed an age whilst we waited. The wind came now in Every
# Closer and closer they drew. The Professor and I crouched down behind Closer
# All at once two voices shouted out to: “Halt!” One was my Jonathan’s, All
# raised in a high key of passion; the other Mr. Morris’ strong resolute Mr
# spoken. Instinctively they reined in, and at the instant Lord Godalming Lord
# and Jonathan dashed up at one side and Dr. Seward and Mr. Morris on the Jonathan
# forward; but the four men raised their Winchester rifles, and in an Winchester
# unmistakable way commanded them to stop. At the same moment Dr. Van Dr
# Helsing and I rose behind the rock and pointed our weapons at them. Helsing
# Seeing that they were surrounded the men tightened their reins and drew Seeing
# The leader, with a quick movement of his rein, threw his horse out in The
# For answer, all four men of our party threw themselves from their horses For
# Jonathan in such danger, but that the ardour of battle must have been Jonathan
# In the midst of this I could see that Jonathan on one side of the ring In
# of men, and Quincey on the other, were forcing a way to the cart; it was Quincey
# box, and flung it over the wheel to the ground. In the meantime, Mr. Mr
# Morris had had to use force to pass through his side of the ring of Morris
# Szgany. All the time I had been breathlessly watching Jonathan I had, Szgany
# beside Jonathan, who had by now jumped from the cart, I could see that Jonathan
# as Jonathan, with desperate energy, attacked one end of the chest, Jonathan
# attempting to prize off the lid with his great Kukri knife, he attacked Kukri
# By this time the gypsies, seeing themselves covered by the Winchesters, By
# and at the mercy of Lord Godalming and Dr. Seward, had given in and made Lord
# shadows of the whole group fell long upon the snow. I saw the Count Count
# As I looked, the eyes saw the sinking sun, and the look of hate in them As
# But, on the instant, came the sweep and flash of Jonathan’s great knife. But
# moment Mr. Morris’s bowie knife plunged into the heart. Mr
# It was like a miracle; but before our very eyes, and almost in the It
# The Castle of Dracula now stood out against the red sky, and every stone The
# The gypsies, taking us as in some way the cause of the extraordinary The
# Mr. Morris, who had sunk to the ground, leaned on his elbow, holding his Mr
# flew to him, for the Holy circle did not now keep me back; so did the Holy
# “I am only too happy to have been of any service! Oh, God!” he cried Oh
# suddenly, struggling up to a sitting posture and pointing to me, “It was It
# worth for this to die! Look! look!” Look
# The sun was now right down upon the mountain top, and the red gleams The
# the men sank on their knees and a deep and earnest “Amen” broke from all Amen
# “Now God be thanked that all has not been in vain! See! the snow is not Now
# more stainless than her forehead! The curse has passed away!” The
# And, to our bitter grief, with a smile and in silence, he died, a And
# NOTE NOTE
# Seven years ago we all went through the flames; and the happiness of Seven
# is an added joy to Mina and to me that our boy’s birthday is the same Mina
# day as that on which Quincey Morris died. His mother holds, I know, the Quincey
# we call him Quincey. Quincey
# In the summer of this year we made a journey to Transylvania, and went In
# When we got home we were talking of the old time--which we could all When
# look back on without despair, for Godalming and Seward are both happily Godalming
# note-books of Mina and Seward and myself, and Van Helsing’s memorandum. Mina
# We could hardly ask any one, even did we wish to, to accept these as We
# proofs of so wild a story. Van Helsing summed it all up as he said, with Helsing
# “We want no proofs; we ask none to believe us! This boy will some day We
# JONATHAN HARKER. JONATHAN
# THE END THE
# _There’s More to Follow!_ There
# More stories of the sort you like; more, probably, by the author of More
# reputation, in the Authors’ Alphabetical List which you will find Authors
# It is a _selected_ list; every book in it has achieved a certain It
# The Grosset & Dunlap list is not only the greatest Index of Good The
# Fiction available, it represents in addition a generally accepted Fiction
# Standard of Value. It will pay you to Standard
# _Look on the Other Side of the Wrapper!_ Look
# _In case the wrapper is lost write to the publishers for a complete In
# DETECTIVE STORIES BY J. S. FLETCHER DETECTIVE
# May be had wherever books are sold. Ask for Grosset & Dunlap’s list May
# THE SECRET OF THE BARBICAN THE
# THE ANNEXATION SOCIETY THE
# THE WOLVES AND THE LAMB THE
# GREEN INK GREEN
# THE KING versus WARGRAVE THE
# THE LOST MR. LINTHWAITE THE
# THE MILL OF MANY WINDOWS THE
# THE HEAVEN-KISSED HILL THE
# THE MIDDLE TEMPLE MURDER THE
# RAVENSDENE COURT RAVENSDENE
# THE RAYNER-SLADE AMALGAMATION THE
# THE SAFETY PIN THE
# THE SECRET WAY THE
# THE VALLEY OF HEADSTRONG MEN THE
# _Ask for Complete free list of G. & D. Popular Copyrighted Fiction_ Ask
# GROSSET & DUNLAP, _Publishers_, NEW YORK GROSSET

# %% [markdown]
# ## Debugging
#
# When you are reading and writing files, debugging can be tricky.
# If you are working in a Jupyter notebook, you can use **shell commands** to help.
# For example, to display the first few lines of a file, you can use the command `!head`, like this:

# %%
# !head pg345_cleaned.txt
# Out:
#                                 DRACULA
#
#                                   _by_
#
#                               Bram Stoker

# %% [markdown]
# The initial exclamation point, `!`, indicates that this is a shell command, which is not part of Python.
# To display the last few lines, you can use `!tail`.

# %%
# !tail pg345_cleaned.txt
# Out:
# _Ask for Complete free list of G. & D. Popular Copyrighted Fiction_
#
# GROSSET & DUNLAP, _Publishers_, NEW YORK

# %% [markdown]
# When you are working with large files, debugging can be difficult because there might be too much output to check by hand.
# A good debugging strategy is to start with just part of the file, get the program working, and then run it with the whole file.
#
# To make a small file that contains part of a larger file, we can use `!head` again with the redirect operator, `>`, which indicates that the results should be written to a file rather than displayed.

# %%
# !head pg345_cleaned.txt > pg345_cleaned_10_lines.txt

# %% [markdown]
# By default, `!head` reads the first 10 lines, but it takes an optional argument that indicates the number of lines to read.

# %%
# !head -100 pg345_cleaned.txt > pg345_cleaned_100_lines.txt

# %% [markdown]
# This shell command reads the first 100 lines from `pg345_cleaned.txt` and writes them to a file called `pg345_cleaned_100_lines.txt`.
#
# Note: The shell commands `!head` and `!tail` are not available on all operating systems.
# If they don't work for you, we can write similar functions in Python.
# See the first exercise at the end of this chapter for suggestions.

# %% [markdown]
# ## Glossary
#
# **sequence:**
#  An ordered collection of values where each value is identified by an integer index.
#
# **character:**
# An element of a string, including letters, numbers, and symbols.
#
# **index:**
#  An integer value used to select an item in a sequence, such as a character in a string. In Python indices start from `0`.
#
# **slice:**
#  A part of a string specified by a range of indices.
#
# **empty string:**
# A string that contains no characters and has length `0`.
#
# **object:**
#  Something a variable can refer to. An object has a type and a value.
#
# **immutable:**
# If the elements of an object cannot be changed, the object is immutable.
#
# **invocation:**
#  An expression -- or part of an expression -- that calls a method.
#
# **regular expression:**
# A sequence of characters that defines a search pattern.
#
# **pattern:**
# A rule that specifies the requirements a string has to meet to constitute a match.
#
# **string substitution:**
# Replacement of a string, or part of a string, with another string.
#
# **shell command:**
# A statement in a shell language, which is a language used to interact with an operating system.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/words.txt');
# Out:
# Downloaded words.txt

# %% [markdown]
# ### Ask a virtual assistant
#
# In this chapter, we only scratched the surface of what regular expressions can do.
# To get an idea of what's possible, ask a virtual assistant, "What are the most common special characters used in Python regular expressions?"
#
# You can also ask for a pattern that matches particular kinds of strings.
# For example, try asking:
#
# * Write a Python regular expression that matches a 10-digit phone number with hyphens.
#
# * Write a Python regular expression that matches a street address with a number and a street name, followed by `ST` or `AVE`.
#
# * Write a Python regular expression that matches a full name with any common title like `Mr` or `Mrs` followed by any number of names beginning with capital letters, possibly with hyphens between some names.
#
# And if you want to see something more complicated, try asking for a regular expression that matches any legal URL.
#
# A regular expression often has the letter `r` before the quotation mark, which indicates that it is a "raw string".
# For more information, ask a virtual assistant, "What is a raw string in Python?"

# %%
from doctest import run_docstring_examples

def run_doctests(func):
    run_docstring_examples(func, globals(), name=func.__name__)

# %% [markdown]
# ### Exercise
#
# See if you can write a function that does the same thing as the shell command `!head`.
# It should take as arguments the name of a file to read, the number of lines to read, and the name of the file to write the lines into.
# If the third parameter is `None`, it should display the lines rather than write them to a file.
#
# Consider asking a virtual assistant for help, but if you do, tell it not to use a `with` statement or a `try` statement.

# %%
# Solution goes here
def head(input, lines=10, output=None):
    file = open(input, 'r')

    if output is not None:
        out = open(output, 'w')

    for i in range(lines):
        line = file.readline()

        if output is not None:
            out.write(line)
        else:
            print(line, end='')
    file.close()

    if output is not None:
        out.close()

# %% [markdown]
# You can use the following examples to test your function.

# %%
head('pg345_cleaned.txt', 10)
# Out:
#                                 DRACULA
#
#                                   _by_
#
#                               Bram Stoker

# %%
head('pg345_cleaned.txt', 100, 'pg345_cleaned_100_lines.txt')

# %%
# !tail pg345_cleaned_100_lines.txt
# Out:
# JONATHAN HARKER’S JOURNAL
#
# (_Kept in shorthand._)
#
#
# _3 May. Bistritz._--Left Munich at 8:35 P. M., on 1st May, arriving at
# Vienna early next morning; should have arrived at 6:46, but train was an
# hour late. Buda-Pesth seems a wonderful place, from the glimpse which I
# got of it from the train and the little I could walk through the
# streets. I feared to go very far from the station, as we had arrived

# %% [markdown]
# ### Exercise
#
# "Wordle" is an online word game where the objective is to guess a five-letter word in six or fewer attempts.
# Each attempt has to be recognized as a word, not including proper nouns.
# After each attempt, you get information about which of the letters you guessed appear in the target word, and which ones are in the correct position.
#
# For example, suppose the target word is `MOWER` and you guess `TRIED`.
# You would learn that `E` is in the word and in the correct position, `R` is in the word but not in the correct position, and `T`, `I`, and `D` are not in the word.
#
# As a different example, suppose you have guessed the words `SPADE` and `CLERK`, and you've learned that `E` is in the word, but not in either of those positions, and none of the other letters appear in the word.
# Of the words in the word list, how many could be the target word?
# Write a function called `check_word` that takes a five-letter word and checks whether it could be the target word, given these guesses.

# %%
# Solution goes here
def check_word(word):
  if 'e' not in word or word[2] == 'e' or word[4] == 'e' or uses_any(word, 'spadclrk'):
        return False

  return True

# %% [markdown]
# You can use any of the functions from the previous chapter, like `uses_any`.

# %%
def uses_any(word, letters):
    for letter in word.lower():
        if letter in letters.lower():
            return True
    return False

# %% [markdown]
# You can use the following loop to test your function.

# %%
for line in open('words.txt'):
    word = line.strip()
    if len(word) == 5 and check_word(word):
        print(word)
# Out:
# befit
# befog
# beget
# begin
# begot
# begum
# begun
# beigy
# being
# bemix
# benni
# benny
# beton
# bewig
# bogey
# boney
# buteo
# ebbet
# ebony
# eight
# embow
# emmet
# enfin
# enjoy
# ennui
# envoi
# envoy
# enzym
# eying
# feign
# feint
# fenny
# feoff
# fogey
# fumet
# gemmy
# gemot
# genet
# genii
# genom
# given
# gooey
# hefty
# heigh
# hemin
# heugh
# homey
# honey
# hooey
# hymen
# jemmy
# jenny
# jeton
# jetty
# meiny
# mezzo
# mizen
# money
# motet
# motey
# neigh
# netty
# nomen
# numen
# often
# quiet
# tenet
# tenon
# tenth
# tenty
# teugh
# thief
# totem
# unmet
# unmew
# veiny
# venin
# venom
# vimen
# vixen
# webby
# weigh
# wenny
# winey
# witen
# wizen
# women
# woven
# xenon
# zibet

# %% [markdown]
# ### Exercise
#
# Continuing the previous exercise, suppose you guess the work `TOTEM` and learn that the `E` is *still* not in the right place, but the `M` is. How many words are left?

# %%
# Solution goes here
def check_word2(word):
  if not check_word(word) or word[3] == 'e' or word[4] != 'm':
        return False

  return True

# %%
# Solution goes here

for line in open('words.txt'):
    word = line.strip()
    if len(word) == 5 and check_word2(word):
        print(word)
# Out:
# begum
# enzym
# genom
# venom

# %% [markdown]
# ### Exercise
#
# *The Count of Monte Cristo* is a novel by Alexandre Dumas that is considered a classic.
# Nevertheless, in the introduction of an English translation of the book, the writer Umberto Eco confesses that he found the book to be "one of the most badly written novels of all time".
#
# In particular, he says it is "shameless in its repetition of the same adjective," and mentions in particular the number of times "its characters either shudder or turn pale."
#
# To see whether his objection is valid, let's count the number number of lines that contain the word `pale` in any form, including `pale`, `pales`, `paled`, and `paleness`, as well as the related word `pallor`.
# Use a single regular expression that matches any of these words.
# As an additional challenge, make sure that it doesn't match any other words, like `impale` -- you might want to ask a virtual assistant for help.

# %% [markdown]
# The following cell downloads the book from Project Gutenberg <https://www.gutenberg.org/ebooks/1184>.

# %%
import os

if not os.path.exists('pg1184.txt'):
    # !wget https://www.gutenberg.org/cache/epub/1184/pg1184.txt
# Out:
# --2025-05-07 11:46:29--  https://www.gutenberg.org/cache/epub/1184/pg1184.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2787202 (2.7M) [text/plain]
# Saving to: ‘pg1184.txt’
#
# pg1184.txt          100%[===================>]   2.66M  14.2MB/s    in 0.2s
#
# 2025-05-07 11:46:29 (14.2 MB/s) - ‘pg1184.txt’ saved [2787202/2787202]

# %% [markdown]
# The following cell runs a function that reads the file from Project Gutenberg and writes a file that contains only the text of the book, not the added information about the book.

# %%
def clean_file(input_file, output_file):
    reader = open(input_file)
    writer = open(output_file, 'w')

    for line in reader:
        if is_special_line(line):
            break

    for line in reader:
        if is_special_line(line):
            break
        writer.write(line)

    reader.close()
    writer.close()

clean_file('pg1184.txt', 'pg1184_cleaned.txt')

# %%
# Solution goes here
def match(pattern):
    conto = 0
    for line in open('pg1184_cleaned.txt'):
        result=re.search(pattern, line)
        if result != None:
            conto = conto + 1
    return conto

# %%
# Solution goes here
pattern = '(pale|pales|paled|pallor|paleness)'
match(pattern)
# Out:
# 239

# %%
# Solution goes here
pattern = r'\b(pale|pales|paled|pallor|paleness)\b'
match(pattern)
# Out:
# 223

# %% [markdown]
# By this count, these words appear on `223` lines of the book, so Mr. Eco might have a point.

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
